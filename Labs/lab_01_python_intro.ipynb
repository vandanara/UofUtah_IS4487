# %% [markdown]
# > ### Note on Labs and Assigments:
# >
# > Throughout this lab, you will see **🔧 Try It Yourself** sections. Some labs may also have a final 🔧 **Reflection** section
# >
# > ✅ You are expected to:
# > - Complete each **"🔧 Try It Yourself”** section by writing and running your own code or answering the prompted questions in a markdown or python cell below the section.
# > 🔧 Look for the **wrench emoji** 🔧 — it highlights where you're expected to take action!
# > - Some labs ask for your **comments/Markdown** or have a **Reflection** section at the end of the lab; answer those in your own words (not AI generated answers). This is your opportunity to summarize what you learned and connect the concepts.
# >
# >
# > These sections with a wrench are graded and are not optional.
# >
# > ---

# %% [markdown]
# # **IS 4487 LAB 1 - PYTHON INTRO**
#
# ## Outline
#
# - Create and format cells in a notebook
# - Create basic variables in Python
#
# <a href="https://colab.research.google.com/github/vandanara/UofUtah_IS4487/blob/main/Labs/lab_01_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# If you have any questions about Colab, you can read more here:  https://research.google.com/colaboratory/faq.html

# %% [markdown]
# ## **Part 1: Markdown**

# %% [markdown]
# ### **🔧 Try It Yourself - Part 1**

# %% [markdown]
# 1. Add a Markdown cell below this cell and write (with bullet points for major and food):
#
# - A heading.
# - Your major
# - Your favorite food

# %% [markdown]
# ## **Part 2: Arithmetic**

# %% [markdown]
# ### **🔧 Try It Yourself - Part 2**

# %% [markdown]
# 2. Add a mathematical formula to add 15 and 22 in the cell below

# %%
#🔧 2. Your code goes here

# %% [markdown]
# ## **Part 3: Print value of variables**

# %% [markdown]
# ### **🔧 Try It Yourself - Part 3**

# %% [markdown]
# 3. Create a variable called "x" with the value "Hello World".  Print the value of the variable

# %% [markdown]
# ## Export Your Notebook to Submit in Canvas
# - **1. Download to local machine**\
# In the top menu, go to *File > Download > Download .ipynb*.
#
# - **2. Upload to Colab virtual machine VM**\
# In the left side menu, click the Files icon, then click the *Upload to Session Storage* icon. Select the above saved file to add it to Colab's temporary (VM) storage.
#
# - **3. Rename and Convert the file to HTML**\
# You will need to rename the file by right clicking it. Add yor last and firstname. Run the cell below but edit it first to match your filename with your LastnameFirstname.  You may be asked to approve access to the files. If done correctly, it will add an html file with the same filename in the VM storage. You can see it in the Files tab on the left.
#
# - **4. Download the HTML file**\
# Download your HTML file (***lab_01_LastnameFirstname.html***) as your completed lab. Please ensure that you change the name to reflect YOUR last name and first name. Then upload to Canvas.

# %%
# !jupyter nbconvert --to html "lab_01_yourLastnameFirstname.ipynb"

# %% [markdown]
# ## Submit your Lab
#
# - Make sure that all of your output is shown.
# When there are multiple subtasks, good ideas to write code for each in its own cell.
# - If you use AI, it is your responsibility to clean up the AI code. Only keep the outputs relevant to each subtask or task question.
# - Upload your HTML file to Canvas. make sure that your lastnamefirstname are part of the filename as requested above
# - Optionally, save your file in your own GitHub account for future use
